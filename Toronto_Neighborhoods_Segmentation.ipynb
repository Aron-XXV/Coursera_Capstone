# %% [markdown]
# # First phase notebook: Segmenting and Clustering Neighborhoods in Toronto
# TOC to be completed later

# %%
# importing libraries
! pip install lxml html5lib beautifulsoup4
import pandas as pd
import numpy as np
import requests
from pandas.io.json import json_normalize
# Out:
# Requirement already satisfied: lxml in c:\users\king aron\anaconda3\lib\site-packages (4.5.0)
# Requirement already satisfied: html5lib in c:\users\king aron\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\king aron\anaconda3\lib\site-packages (4.8.2)
# Requirement already satisfied: webencodings in c:\users\king aron\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\king aron\anaconda3\lib\site-packages (from html5lib) (1.14.0)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\king aron\anaconda3\lib\site-packages (from beautifulsoup4) (1.9.5)
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the 'c:\users\king aron\anaconda3\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ## 1st step, importing the dataset
# in this step the dataset is read using pandas library. Then its 5 first row printed. The desired table is stored in the first table of url.

# %%
# importing dataset
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
df = pd.read_html(url)[0]
df.head()
# Out:
#   Postal Code           Borough              Neighbourhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# ## 2nd step, cleaning and forming the dataset
# According to the provided instruction, unique postal codes are analysed. Becasue the number of unique codes are the same of the current recodes, there is no need of merging or combining rows. In the next stage, Borough without assigned values are deleted. Then neigbourhoods without assigned value are investigated. Becasue there are no rows with such a specification, no cell is replaced with its borough. Finally, the shape of the dataset is printed and the last 5 rows are shown.

# %%
# cleaning and forming the dataset
print('The dataset includes {} records with {} unique postal codes \n'.format(len(df) , len(df['Postal Code'].unique())))
# igonring cells that Borough is not assigned
df = df[df['Borough'] != 'Not assigned']
df.reset_index(inplace = True, drop = True)
print('Aftering deleting rows without assigned boroughs, the number of records reduced to {} \n'.format(len(df)))
# assigning Borough to Neighbourhood where Neighbourhood is 'Not assigned'
n_na_neighbour = df['Neighbourhood'][df['Neighbourhood'] == 'Not assigned'].count()
print('After correcting NA boroughs, {} neighbourhoods found without assigned value \n'.format(n_na_neighbour))
print('the final shape of the dataset is {} \n'.format(df.shape))
df.tail()
# Out:
# The dataset includes 180 records with 180 unique postal codes
#
# Aftering deleting rows without assigned boroughs, the number of records reduced to 103
#
# After correcting NA Boroughs, 0 neighbourhoods found without assigned value
#
# the final shape of the dataset is (103, 3)
#     Postal Code           Borough  \
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100  Business reply mail Processing Centre, South C...
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102  Mimico NW, The Queensway West, South of Bloor,...

# %% [markdown]
# ## 3rd step, transforming the database
# In the next phase of the project, each neighbourhood's coordinates should be found. So, having their name stored in a single cell is not desirable. The ideal form of dataset is having neighbourhood name in a cell, preferably set as index.

# %%
# creating a dataset setting each neighbourhood in one row
dfn = pd.DataFrame(columns = ['Postal Code', 'Borough', 'Neighbourhood'])
for nn in range(0, len(df) - 1):
    borough = df['Borough'].iloc[nn]
    post_code = df['Postal Code'].iloc[nn]
    neighbourhoods = df['Neighbourhood'].iloc[nn].split(', ')
    for neighbourhood in neighbourhoods: 
        dfn_add = pd.DataFrame({'Borough': [borough], 'Postal Code': [post_code], 'Neighbourhood' : [neighbourhood]})
        dfn = dfn.append(dfn_add, ignore_index=True)
print('the dataset includes {} neighbourhoods \n'.format(len(dfn)))
dfn.tail()
# Out:
# the dataset includes 212 neighbourhoods
#     Postal Code    Borough             Neighbourhood
# 207         M8Y  Etobicoke                Humber Bay
# 208         M8Y  Etobicoke                 Mimico NE
# 209         M8Y  Etobicoke        The Queensway East
# 210         M8Y  Etobicoke     Royal York South East
# 211         M8Y  Etobicoke  Kingsway Park South East

# %% [markdown]
# ## 4th step, finding coordinates
# According to the provided instructions of the assignment, geocoder is used in a while loop to find the corresponding long/lat of each rows in the newly transformed dataset. Unfortunately, it has not ended to any plausible result. So, I used instead geopy which made it possible. Two columns have been added to the new dataset.
# there are several differences which made the code into work:
# 1. using geopy, Nominatim
# 2. passing GeocoderTimedOut for avoiding errors of timing out
# 3. setting a search limit for a neighbourhood
# 4. using sleep of 1 sec for avoiding server runtime limit block
# 5. passing a random symbolic password
# 6. random ordering of address
# <br>
#
# Finally, geocoder fails to locate some neibourhoods. These records should be handled manually.

# %%
# !pip install geopy
import geopy
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
# Out:
# Requirement already satisfied: geopy in c:\users\king aron\anaconda3\lib\site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\users\king aron\anaconda3\lib\site-packages (from geopy) (1.50)
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the 'c:\users\king aron\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
def do_geocode(address):
    geopy = Nominatim(user_agent="aron.shirazi@gmail.com")
    try:
        sleep(1)
        return geopy.geocode(address)
    except GeocoderTimedOut:
        return do_geocode(address)

dfn['latitude'] = 'NA'
dfn['longitude'] = 'NA'
max_try = 10
for nn in range(0, len(dfn)):
    neighbourhood = dfn['Neighbourhood'].iloc[nn]
    location = None
    count = 0
    while (location == None) & (count < max_try):
        password = ''.join(random.choice(['#', '$', '%', '@', '*', '-', '&', '~', '!']) for i in range(8))
        address_list = [neighbourhood, 'Toronto', 'Ontario', password]
        order = ''.join(random.sample(['0', '1', '2', '3'], 4))
        n0 = int(order[0]); n1 = int(order[1]); n2 = int(order[2]); n3 = int(order[3])
        address = '{}, {}, {}, {}'.format(address_list[n0], address_list[n1], address_list[n2], address_list[n3])
        location = do_geocode(address)
        count += 1
    if location is not None:
        print('{}, coordinates found for {}'.format(nn, neighbourhood))
        dfn['latitude'].iloc[nn] = location.latitude
        dfn['longitude'].iloc[nn] = location.longitude
    else:
        print('{}, coordinates not found for {}'.format(nn, neighbourhood))
# Out:
# 0, coordinates found for Parkwoods
# 1, coordinates found for Victoria Village
# 2, coordinates found for Regent Park
# 3, coordinates found for Harbourfront
# 4, coordinates found for Lawrence Manor
# 5, coordinates found for Lawrence Heights
# 6, coordinates found for Queen's Park
# 7, coordinates not found for Ontario Provincial Government
# 8, coordinates found for Islington Avenue
# 9, coordinates found for Humber Valley Village
# 10, coordinates found for Malvern
# 11, coordinates found for Rouge
# 12, coordinates found for Don Mills
# 13, coordinates found for Parkview Hill
# 14, coordinates found for Woodbine Gardens
# 15, coordinates found for Garden District
# 16, coordinates found for Ryerson
# 17, coordinates found for Glencairn
# 18, coordinates found for West Deane Park
# 19, coordinates found for Princess Gardens
# 20, coordinates found for Martin Grove
# 21, coordinates found for Islington
# 22, coordinates found for Cloverdale
# 23, coordinates found for Rouge Hill
# 24, coordinates found for Port Union
# 25, coordinates found for Highland Creek
# 26, coordinates found for Don Mills
# 27, coordinates found for Woodbine Heights
# 28, coordinates found for St. James Town
# 29, coordinates found for Humewood-Cedarvale
# 30, coordinates found for Eringate
# 31, coordinates found for Bloordale Gardens
# 32, coordinates found for Old Burnhamthorpe
# 33, coordinates found for Markland Wood
# 34, coordinates found for Guildwood
# 35, coordinates found for Morningside
# 36, coordinates found for West Hill
# 37, coordinates found for The Beaches
# 38, coordinates found for Berczy Park
# 39, coordinates not found for Caledonia-Fairbanks
# 40, coordinates found for Woburn
# 41, coordinates found for Leaside
# 42, coordinates found for Central Bay Street
# 43, coordinates found for Christie
# 44, coordinates found for Cedarbrae
# 45, coordinates found for Hillcrest Village
# 46, coordinates found for Bathurst Manor
# 47, coordinates found for Wilson Heights
# 48, coordinates found for Downsview North
# 49, coordinates found for Thorncliffe Park
# 50, coordinates found for Richmond
# 51, coordinates found for Adelaide
# 52, coordinates found for King
# 53, coordinates found for Dufferin
# 54, coordinates found for Dovercourt Village
# 55, coordinates found for Scarborough Village
# 56, coordinates found for Fairview
# 57, coordinates found for Henry Farm
# 58, coordinates found for Oriole
# 59, coordinates found for Northwood Park
# 60, coordinates found for York University
# 61, coordinates found for East Toronto
# 62, coordinates found for Broadview North (Old East York)
# 63, coordinates found for Harbourfront East
# 64, coordinates found for Union Station
# 65, coordinates found for Toronto Islands
# 66, coordinates found for Little Portugal
# 67, coordinates found for Trinity
# 68, coordinates found for Kennedy Park
# 69, coordinates found for Ionview
# 70, coordinates found for East Birchmount Park
# 71, coordinates found for Bayview Village
# 72, coordinates found for Downsview
# 73, coordinates found for The Danforth West
# 74, coordinates found for Riverdale
# 75, coordinates found for Toronto Dominion Centre
# 76, coordinates found for Design Exchange
# 77, coordinates found for Brockton
# 78, coordinates found for Parkdale Village
# 79, coordinates found for Exhibition Place
# 80, coordinates found for Golden Mile
# 81, coordinates found for Clairlea
# 82, coordinates found for Oakridge
# 83, coordinates found for York Mills
# 84, coordinates found for Silver Hills
# 85, coordinates found for Downsview
# 86, coordinates found for India Bazaar
# 87, coordinates found for The Beaches West
# 88, coordinates found for Commerce Court
# 89, coordinates found for Victoria Hotel
# 90, coordinates found for North Park
# 91, coordinates found for Maple Leaf Park
# 92, coordinates found for Upwood Park
# 93, coordinates found for Humber Summit
# 94, coordinates found for Cliffside
# 95, coordinates found for Cliffcrest
# 96, coordinates found for Scarborough Village West
# 97, coordinates found for Willowdale
# 98, coordinates found for Newtonbrook
# 99, coordinates found for Downsview
# 100, coordinates not found for Studio District
# 101, coordinates found for Bedford Park
# 102, coordinates found for Lawrence Manor East
# 103, coordinates found for Del Ray
# 104, coordinates found for Mount Dennis
# 105, coordinates not found for Keelsdale and Silverthorn
# 106, coordinates found for Humberlea
# 107, coordinates found for Emery
# 108, coordinates found for Birch Cliff
# 109, coordinates found for Cliffside West
# 110, coordinates found for Willowdale
# 111, coordinates found for Willowdale East
# 112, coordinates found for Downsview
# 113, coordinates found for Lawrence Park
# 114, coordinates found for Roselawn
# 115, coordinates found for Runnymede
# 116, coordinates found for The Junction North
# 117, coordinates found for Weston
# 118, coordinates found for Dorset Park
# 119, coordinates found for Wexford Heights
# 120, coordinates found for Scarborough Town Centre
# 121, coordinates found for York Mills West
# 122, coordinates found for Davisville North
# 123, coordinates found for Forest Hill North & West
# 124, coordinates found for Forest Hill Road Park
# 125, coordinates found for High Park
# 126, coordinates found for The Junction South
# 127, coordinates found for Westmount
# 128, coordinates found for Wexford
# 129, coordinates found for Maryvale
# 130, coordinates found for Willowdale
# 131, coordinates found for Willowdale West
# 132, coordinates found for North Toronto West
# 133, coordinates found for Lawrence Park
# 134, coordinates found for The Annex
# 135, coordinates found for North Midtown
# 136, coordinates found for Yorkville
# 137, coordinates found for Parkdale
# 138, coordinates found for Roncesvalles
# 139, coordinates not found for Canada Post Gateway Processing Centre
# 140, coordinates found for Kingsview Village
# 141, coordinates found for St. Phillips
# 142, coordinates found for Martin Grove Gardens
# 143, coordinates found for Richview Gardens
# 144, coordinates found for Agincourt
# 145, coordinates found for Davisville
# 146, coordinates found for University of Toronto
# 147, coordinates found for Harbord
# 148, coordinates found for Runnymede
# 149, coordinates found for Swansea
# 150, coordinates found for Clarks Corners
# 151, coordinates found for Tam O'Shanter
# 152, coordinates found for Sullivan
# 153, coordinates found for Moore Park
# 154, coordinates found for Summerhill East
# 155, coordinates found for Kensington Market
# 156, coordinates found for Chinatown
# 157, coordinates found for Grange Park
# 158, coordinates found for Milliken
# 159, coordinates found for Agincourt North
# 160, coordinates found for Steeles East
# 161, coordinates found for L'Amoreaux East
# 162, coordinates found for Summerhill West
# 163, coordinates found for Rathnelly
# 164, coordinates found for South Hill
# 165, coordinates found for Forest Hill SE
# 166, coordinates found for Deer Park
# 167, coordinates found for CN Tower
# 168, coordinates found for King and Spadina
# 169, coordinates found for Railway Lands
# 170, coordinates found for Harbourfront West
# 171, coordinates found for Bathurst Quay
# 172, coordinates found for South Niagara
# 173, coordinates found for Island airport
# 174, coordinates found for New Toronto
# 175, coordinates found for Mimico South
# 176, coordinates not found for Humber Bay Shores
# 177, coordinates found for South Steeles
# 178, coordinates found for Silverstone
# 179, coordinates found for Humbergate
# 180, coordinates found for Jamestown
# 181, coordinates found for Mount Olive
# 182, coordinates not found for Beaumond Heights
# 183, coordinates found for Thistletown
# 184, coordinates found for Albion Gardens
# 185, coordinates found for Steeles West
# 186, coordinates found for L'Amoreaux West
# 187, coordinates found for Rosedale
# 188, coordinates not found for Stn A PO Boxes
# 189, coordinates found for Alderwood
# 190, coordinates found for Long Branch
# 191, coordinates found for Northwest
# 192, coordinates not found for West Humber - Clairville
# 193, coordinates found for Upper Rouge
# 194, coordinates found for St. James Town
# 195, coordinates found for Cabbagetown
# 196, coordinates found for First Canadian Place
# 197, coordinates found for Underground city
# 198, coordinates found for The Kingsway
# 199, coordinates found for Montgomery Road
# 200, coordinates found for Old Mill North
# 201, coordinates found for Church and Wellesley
# 202, coordinates not found for Business reply mail Processing Centre
# 203, coordinates not found for South Central Letter Processing Plant Toronto
# 204, coordinates found for Old Mill South
# 205, coordinates found for King's Mill Park
# 206, coordinates found for Sunnylea
# 207, coordinates found for Humber Bay
# 208, coordinates found for Mimico NE
# 209, coordinates found for The Queensway East
# 210, coordinates found for Royal York South East
# 211, coordinates found for Kingsway Park South East

# %%
# finding unlocated neighbourhoods to set the m manually
dfn['latitude'][~dfn['latitude'].apply(np.isreal)] = '0'
dfn['longitude'][~dfn['longitude'].apply(np.isreal)] = '0'
dfn['latitude'] = dfn['latitude'].astype('float', errors='ignore')
dfn['longitude'] = dfn['longitude'].astype('float', errors='ignore')
dfn.dtypes
# Out:
# C:\Users\King Aron\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\King Aron\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# Postal Code       object
# Borough           object
# Neighbourhood     object
# latitude         float64
# longitude        float64
# dtype: object

# %%
dfo = pd.read_csv('Geospatial_Coordinates.csv')
for nn in dfn[dfn['longitude'] == 0].index:
    dfn['latitude'].iloc[nn] = float(dfo['Latitude'][dfo['Postal Code'] == dfn['Postal Code'].iloc[nn]])
    dfn['longitude'].iloc[nn] = float(dfo['Longitude'][dfo['Postal Code'] == dfn['Postal Code'].iloc[nn]])
# Out:
# C:\Users\King Aron\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
dfn.head(10)
# Out:
#   Postal Code           Borough                  Neighbourhood   latitude  \
# 0         M3A        North York                      Parkwoods  43.758800
# 1         M4A        North York               Victoria Village  43.732658
# 2         M5A  Downtown Toronto                    Regent Park  43.660706
# 3         M5A  Downtown Toronto                   Harbourfront  43.640080
# 4         M6A        North York                 Lawrence Manor  43.722079
# 5         M6A        North York               Lawrence Heights  43.722778
# 6         M7A  Downtown Toronto                   Queen's Park  43.659659
# 7         M7A  Downtown Toronto  Ontario Provincial Government  43.662301
# 8         M9A         Etobicoke               Islington Avenue  43.606597
# 9         M9A         Etobicoke          Humber Valley Village  43.666472
#
#    longitude
# 0 -79.320197
# 1 -79.311189
# 2 -79.360457
# 3 -79.380150
# 4 -79.437507
# 5 -79.450933
# 6 -79.390340
# 7 -79.389494
# 8 -79.506456
# 9 -79.524314

# %%
from sklearn.cluster import KMeans
#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# %%
# finding the center of map for illustration purpuse
df_loc = dfn[dfn['Neighbourhood'] != 'South Niagara'] # South Niagra is far away and makes our analysis inefficient so it is omitted
center_lat = df_loc['latitude'].mean()
center_lon = df_loc['longitude'].mean()
# to set boundaries of folium
lat_min = df_loc['latitude'].min()
lat_max = df_loc['latitude'].max()
lon_min = df_loc['longitude'].min()
lon_max = df_loc['longitude'].max()

# %%
map_toronto = folium.Map(location=[center_lat, center_lon], width=750, height=500)
map_toronto.fit_bounds([[lat_min, lon_min], [lat_max, lon_max]])
# add markers to map
for lat, lng, label in zip(df_loc['latitude'], df_loc['longitude'], df_loc['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Defining Foursquare Credentials and Version
# @hidden_cell
CLIENT_ID = 'XRZP0Y5N1UHOVN30BRXKVHXNHP2DKVOPKWAUHZUG32VQTLPA' # your Foursquare ID
CLIENT_SECRET = 'YDJPYTGZTRMKPD21E5HQQ2NDSKQM1DTRLM3RR0NPICCZN3XZ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

def find_venue(lat, lon, limit = 100, radius = 500):
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    lat, 
    lon, 
    radius, 
    limit)
    results = requests.get(url).json()
    venues = results['response']['groups'][0]['items']
    nearby_venues = None
    if len(venues) > 0:
        nearby_venues = pd.json_normalize(venues) # flatten JSON
        # filter columns
        filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
        nearby_venues =nearby_venues.loc[:, filtered_columns]
        # filter the category for each row
        nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)
        # clean columns
        nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
    return nearby_venues

# %%
df_venues = pd.DataFrame(columns = ['name', 'categories', 'lat', 'lng'])
nn = 0
for name, lat, lng in zip(df_loc['Neighbourhood'], df_loc['latitude'], df_loc['longitude']):
    df_tr = find_venue(lat, lon)
    if df_tr is None: 
        len_found = 0 
    else: 
        len_found = len(df_tr)
        df_tr['neighbourhood'] = name
    print('{}, venues of {} explored at lat: {} and long: {}, with {} venues'.format(nn, name, lat, lng, len_found))
    df_venues = pd.concat([df_venues, df_tr])
    nn += 1
df_venues.reset_index(inplace = True, drop = True)
print('venues of Toronto are explored, the dataset shape is {} \n'.format(df_venues.shape))
df_venues
# Out:
# 0, venues of Parkwoods explored at lat: 43.7587999 and long: -79.3201966, with 18 venues
# 1, venues of Victoria Village explored at lat: 43.732658 and long: -79.3111892, with 4 venues
# 2, venues of Regent Park explored at lat: 43.6607056 and long: -79.3604569, with 0 venues
# 3, venues of Harbourfront explored at lat: 43.6400801 and long: -79.3801495, with 0 venues
# 4, venues of Lawrence Manor explored at lat: 43.7220788 and long: -79.4375067, with 2 venues
# 5, venues of Lawrence Heights explored at lat: 43.7227784 and long: -79.4509332, with 3 venues
# 6, venues of Queen's Park explored at lat: 43.659659 and long: -79.3903399, with 0 venues
# 7, venues of Ontario Provincial Government explored at lat: 43.6623015 and long: -79.3894938, with 0 venues
# 8, venues of Islington Avenue explored at lat: 43.6065969 and long: -79.5064562, with 0 venues
# 9, venues of Humber Valley Village explored at lat: 43.6664717 and long: -79.5243136, with 0 venues
# 10, venues of Malvern explored at lat: 43.8091955 and long: -79.2217008, with 15 venues
# 11, venues of Rouge explored at lat: 43.8049304 and long: -79.1658374, with 10 venues
# 12, venues of Don Mills explored at lat: 43.775347 and long: -79.3459439, with 2 venues
# 13, venues of Parkview Hill explored at lat: 43.6534817 and long: -79.3839347, with 0 venues
# 14, venues of Woodbine Gardens explored at lat: 43.7233296 and long: -79.2993483, with 2 venues
# 15, venues of Garden District explored at lat: 43.6564995 and long: -79.3771141, with 0 venues
# 16, venues of Ryerson explored at lat: 43.65846945 and long: -79.37899327245886, with 0 venues
# 17, venues of Glencairn explored at lat: 43.7087117 and long: -79.4406853, with 1 venues
# 18, venues of West Deane Park explored at lat: 43.6631995 and long: -79.5685684, with 0 venues
# 19, venues of Princess Gardens explored at lat: 43.6404664 and long: -79.3912237, with 0 venues
# 20, venues of Martin Grove explored at lat: 43.6534817 and long: -79.3839347, with 0 venues
# 21, venues of Islington explored at lat: 43.6493074 and long: -79.54509626200098, with 0 venues
# 22, venues of Cloverdale explored at lat: 43.623716 and long: -79.5500753999574, with 0 venues
# 23, venues of Rouge Hill explored at lat: 43.7802711 and long: -79.1304992, with 0 venues
# 24, venues of Port Union explored at lat: 43.7755039 and long: -79.1349765, with 2 venues
# 25, venues of Highland Creek explored at lat: 43.7901172 and long: -79.1733344, with 2 venues
# 26, venues of Don Mills explored at lat: 43.775347 and long: -79.3459439, with 2 venues
# 27, venues of Woodbine Heights explored at lat: 43.69992 and long: -79.319279, with 0 venues
# 28, venues of St. James Town explored at lat: 43.6708625 and long: -79.37279241253721, with 0 venues
# 29, venues of Humewood-Cedarvale explored at lat: 43.690844350000006 and long: -79.4249313241846, with 0 venues
# 30, venues of Eringate explored at lat: 43.6601339 and long: -79.5838863579333, with 0 venues
# 31, venues of Bloordale Gardens explored at lat: 43.662394 and long: -79.4465194, with 0 venues
# 32, venues of Old Burnhamthorpe explored at lat: 43.6508593 and long: -79.593177, with 0 venues
# 33, venues of Markland Wood explored at lat: 43.63123865 and long: -79.58543401986114, with 0 venues
# 34, venues of Guildwood explored at lat: 43.7906715 and long: -79.19364614400352, with 2 venues
# 35, venues of Morningside explored at lat: 43.7906715 and long: -79.19364614400352, with 2 venues
# 36, venues of West Hill explored at lat: 43.7689144 and long: -79.1872905, with 5 venues
# 37, venues of The Beaches explored at lat: 43.689953200000005 and long: -79.32493147310899, with 0 venues
# 38, venues of Berczy Park explored at lat: 43.64798435 and long: -79.37539591138858, with 0 venues
# 39, venues of Caledonia-Fairbanks explored at lat: 43.6890256 and long: -79.453512, with 0 venues
# 40, venues of Woburn explored at lat: 43.7598243 and long: -79.2252908, with 20 venues
# 41, venues of Leaside explored at lat: 43.7047983 and long: -79.3680904, with 1 venues
# 42, venues of Central Bay Street explored at lat: 43.6561192 and long: -79.38467, with 0 venues
# 43, venues of Christie explored at lat: 43.6641106 and long: -79.4184051, with 0 venues
# 44, venues of Cedarbrae explored at lat: 43.75646655 and long: -79.22669244258802, with 9 venues
# 45, venues of Hillcrest Village explored at lat: 43.6816953 and long: -79.4257118, with 0 venues
# 46, venues of Bathurst Manor explored at lat: 43.7286206 and long: -79.4316089, with 4 venues
# 47, venues of Wilson Heights explored at lat: 43.7405195 and long: -79.4400172, with 13 venues
# 48, venues of Downsview North explored at lat: 43.7492988 and long: -79.462248, with 3 venues
# 49, venues of Thorncliffe Park explored at lat: 43.704553 and long: -79.3454074, with 1 venues
# 50, venues of Richmond explored at lat: 43.6485875 and long: -79.3913729, with 0 venues
# 51, venues of Adelaide explored at lat: 43.65082325 and long: -79.37793584643234, with 0 venues
# 52, venues of King explored at lat: 43.65082325 and long: -79.37793584643234, with 0 venues
# 53, venues of Dufferin explored at lat: 43.6602019 and long: -79.4357191, with 0 venues
# 54, venues of Dovercourt Village explored at lat: 43.6653069 and long: -79.4326362, with 0 venues
# 55, venues of Scarborough Village explored at lat: 43.7468707 and long: -79.1996733, with 8 venues
# 56, venues of Fairview explored at lat: 43.6534817 and long: -79.3839347, with 0 venues
# 57, venues of Henry Farm explored at lat: 43.7628215 and long: -79.36068230612244, with 17 venues
# 58, venues of Oriole explored at lat: 43.765498 and long: -79.3642688, with 5 venues
# 59, venues of Northwood Park explored at lat: 43.766842749999995 and long: -79.49250837302188, with 4 venues
# 60, venues of York University explored at lat: 43.653566999999995 and long: -79.40549604487205, with 0 venues
# 61, venues of East Toronto explored at lat: 43.6534817 and long: -79.3839347, with 0 venues
# 62, venues of Broadview North (Old East York) explored at lat: 43.6839242 and long: -79.3569642, with 0 venues
# 63, venues of Harbourfront East explored at lat: 43.6400801 and long: -79.3801495, with 0 venues
# 64, venues of Union Station explored at lat: 43.7796268 and long: -79.1400466, with 0 venues
# 65, venues of Toronto Islands explored at lat: 43.6230544 and long: -79.39431563721035, with 0 venues
# 66, venues of Little Portugal explored at lat: 43.64741325 and long: -79.43111632546047, with 0 venues
# 67, venues of Trinity explored at lat: 43.665301549999995 and long: -79.39525214965947, with 0 venues
# 68, venues of Kennedy Park explored at lat: 43.724878 and long: -79.2539688, with 3 venues
# 69, venues of Ionview explored at lat: 43.7359904 and long: -79.2765146, with 7 venues
# 70, venues of East Birchmount Park explored at lat: 43.7141672 and long: -79.271109, with 1 venues
# 71, venues of Bayview Village explored at lat: 43.7685073 and long: -79.3848826, with 5 venues
# 72, venues of Downsview explored at lat: 43.7492988 and long: -79.462248, with 3 venues
# 73, venues of The Danforth West explored at lat: 43.6135303 and long: -79.3434119, with 0 venues
# 74, venues of Riverdale explored at lat: 43.6654704 and long: -79.3525936, with 0 venues
# 75, venues of Toronto Dominion Centre explored at lat: 43.6473768 and long: -79.3813719429129, with 0 venues
# 76, venues of Design Exchange explored at lat: 43.6477412 and long: -79.3801145, with 0 venues
# 77, venues of Brockton explored at lat: 43.6509173 and long: -79.4400216, with 0 venues
# 78, venues of Parkdale Village explored at lat: 43.638093 and long: -79.4665843, with 0 venues
# 79, venues of Exhibition Place explored at lat: 43.6335375 and long: -79.41771134645269, with 0 venues
# 80, venues of Golden Mile explored at lat: 43.7278414 and long: -79.2876217, with 4 venues
# 81, venues of Clairlea explored at lat: 43.7088231 and long: -79.2959856, with 1 venues
# 82, venues of Oakridge explored at lat: 43.6832979 and long: -79.2817887, with 0 venues
# 83, venues of York Mills explored at lat: 43.7392676 and long: -79.4217072, with 13 venues
# 84, venues of Silver Hills explored at lat: 43.7628215 and long: -79.36068230612244, with 17 venues
# 85, venues of Downsview explored at lat: 43.72882 and long: -79.48204482517002, with 4 venues
# 86, venues of India Bazaar explored at lat: 43.6724724 and long: -79.3220909, with 0 venues
# 87, venues of The Beaches West explored at lat: 43.689953200000005 and long: -79.32493147310899, with 0 venues
# 88, venues of Commerce Court explored at lat: 43.64809515 and long: -79.37902543099575, with 0 venues
# 89, venues of Victoria Hotel explored at lat: 43.6523873 and long: -79.3835641, with 0 venues
# 90, venues of North Park explored at lat: 43.7228698 and long: -79.48448599257934, with 2 venues
# 91, venues of Maple Leaf Park explored at lat: 43.7158241 and long: -79.49341621107953, with 0 venues
# 92, venues of Upwood Park explored at lat: 43.708654499999994 and long: -79.50254644741823, with 1 venues
# 93, venues of Humber Summit explored at lat: 43.7600778 and long: -79.5717598, with 20 venues
# 94, venues of Cliffside explored at lat: 43.7014783 and long: -79.253777, with 1 venues
# 95, venues of Cliffcrest explored at lat: 43.7218363 and long: -79.2362138, with 2 venues
# 96, venues of Scarborough Village West explored at lat: 43.7437422 and long: -79.2116324, with 9 venues
# 97, venues of Willowdale explored at lat: 43.7615095 and long: -79.4109234, with 18 venues
# 98, venues of Newtonbrook explored at lat: 43.7938863 and long: -79.42567902301055, with 6 venues
# 99, venues of Downsview explored at lat: 43.72882 and long: -79.48204482517002, with 4 venues
# 100, venues of Studio District explored at lat: 43.6595255 and long: -79.340923, with 0 venues
# 101, venues of Bedford Park explored at lat: 43.7398265 and long: -79.418975, with 10 venues
# 102, venues of Lawrence Manor East explored at lat: 43.7220788 and long: -79.4375067, with 2 venues
# 103, venues of Del Ray explored at lat: 43.6924409 and long: -79.4911318, with 0 venues
# 104, venues of Mount Dennis explored at lat: 43.6869597 and long: -79.4895513, with 0 venues
# 105, venues of Keelsdale and Silverthorn explored at lat: 43.6911158 and long: -79.47601329999999, with 0 venues
# 106, venues of Humberlea explored at lat: 43.717965500000005 and long: -79.51598027144377, with 1 venues
# 107, venues of Emery explored at lat: 43.7520744 and long: -79.5423657, with 4 venues
# 108, venues of Birch Cliff explored at lat: 43.6918051 and long: -79.2644935, with 0 venues
# 109, venues of Cliffside West explored at lat: 43.7014783 and long: -79.253777, with 1 venues
# 110, venues of Willowdale explored at lat: 43.7660167 and long: -79.41445238741419, with 4 venues
# 111, venues of Willowdale East explored at lat: 43.7660167 and long: -79.41445238741419, with 4 venues
# 112, venues of Downsview explored at lat: 43.7492988 and long: -79.462248, with 3 venues
# 113, venues of Lawrence Park explored at lat: 43.728800750000005 and long: -79.38371574291823, with 4 venues
# 114, venues of Roselawn explored at lat: 43.7022339 and long: -79.4411291, with 1 venues
# 115, venues of Runnymede explored at lat: 43.6517026 and long: -79.4759978, with 0 venues
# 116, venues of The Junction North explored at lat: 43.6654775 and long: -79.470352, with 0 venues
# 117, venues of Weston explored at lat: 43.7001608 and long: -79.5162474, with 0 venues
# 118, venues of Dorset Park explored at lat: 43.7528467 and long: -79.282067, with 4 venues
# 119, venues of Wexford Heights explored at lat: 43.7432421 and long: -79.304641, with 9 venues
# 120, venues of Scarborough Town Centre explored at lat: 43.7761341 and long: -79.25843763592165, with 2 venues
# 121, venues of York Mills West explored at lat: 43.7440391 and long: -79.406657, with 9 venues
# 122, venues of Davisville North explored at lat: 43.697936 and long: -79.3972908, with 0 venues
# 123, venues of Forest Hill North & West explored at lat: 43.701028 and long: -79.4255998, with 1 venues
# 124, venues of Forest Hill Road Park explored at lat: 43.7003347 and long: -79.4144612, with 0 venues
# 125, venues of High Park explored at lat: 43.638093 and long: -79.4665843, with 0 venues
# 126, venues of The Junction South explored at lat: 43.6654775 and long: -79.470352, with 0 venues
# 127, venues of Westmount explored at lat: 43.68165165 and long: -79.50316782490798, with 0 venues
# 128, venues of Wexford explored at lat: 43.7453767 and long: -79.2947155, with 7 venues
# 129, venues of Maryvale explored at lat: 43.7590508 and long: -79.3102297, with 19 venues
# 130, venues of Willowdale explored at lat: 43.7615095 and long: -79.4109234, with 18 venues
# 131, venues of Willowdale West explored at lat: 43.7660167 and long: -79.41445238741419, with 4 venues
# 132, venues of North Toronto West explored at lat: 43.6449033 and long: -79.3818364, with 0 venues
# 133, venues of Lawrence Park explored at lat: 43.729199 and long: -79.4032525, with 4 venues
# 134, venues of The Annex explored at lat: 43.6703377 and long: -79.407117, with 0 venues
# 135, venues of North Midtown explored at lat: 43.7057358 and long: -79.39756691740916, with 1 venues
# 136, venues of Yorkville explored at lat: 43.6713861 and long: -79.3901677, with 0 venues
# 137, venues of Parkdale explored at lat: 43.6404954 and long: -79.4368965, with 0 venues
# 138, venues of Roncesvalles explored at lat: 43.6514426 and long: -79.4510381, with 0 venues
# 139, venues of Canada Post Gateway Processing Centre explored at lat: 43.6369656 and long: -79.61581899999999, with 0 venues
# 140, venues of Kingsview Village explored at lat: 43.7062871 and long: -79.5512543, with 1 venues
# 141, venues of St. Phillips explored at lat: 43.7062871 and long: -79.5512543, with 1 venues
# 142, venues of Martin Grove Gardens explored at lat: 43.68892305 and long: -79.57787072475531, with 0 venues
# 143, venues of Richview Gardens explored at lat: 43.683395250000004 and long: -79.54112657809445, with 0 venues
# 144, venues of Agincourt explored at lat: 43.7853531 and long: -79.2785494, with 4 venues
# 145, venues of Davisville explored at lat: 43.6977732 and long: -79.39690388301321, with 0 venues
# 146, venues of University of Toronto explored at lat: 43.663461999999996 and long: -79.39775965337452, with 0 venues
# 147, venues of Harbord explored at lat: 43.66151215 and long: -79.41439133503991, with 0 venues
# 148, venues of Runnymede explored at lat: 43.6517026 and long: -79.4759978, with 0 venues
# 149, venues of Swansea explored at lat: 43.638093 and long: -79.4665843, with 0 venues
# 150, venues of Clarks Corners explored at lat: 43.7964095 and long: -79.2977951, with 5 venues
# 151, venues of Tam O'Shanter explored at lat: 43.7810454 and long: -79.2980941, with 0 venues
# 152, venues of Sullivan explored at lat: 43.7726802 and long: -79.3159449, with 2 venues
# 153, venues of Moore Park explored at lat: 43.68126565 and long: -79.39077530238976, with 0 venues
# 154, venues of Summerhill East explored at lat: 43.6816776 and long: -79.3905037, with 0 venues
# 155, venues of Kensington Market explored at lat: 43.6552136 and long: -79.4022604, with 0 venues
# 156, venues of Chinatown explored at lat: 43.6529237 and long: -79.3980316, with 0 venues
# 157, venues of Grange Park explored at lat: 43.652196599999996 and long: -79.39231921757992, with 0 venues
# 158, venues of Milliken explored at lat: 43.812936 and long: -79.29398666572772, with 4 venues
# 159, venues of Agincourt North explored at lat: 43.8080383 and long: -79.2664391, with 15 venues
# 160, venues of Steeles East explored at lat: 43.8161778 and long: -79.3145378, with 2 venues
# 161, venues of L'Amoreaux East explored at lat: 43.799003 and long: -79.3059669, with 4 venues
# 162, venues of Summerhill West explored at lat: 43.6816776 and long: -79.3905037, with 0 venues
# 163, venues of Rathnelly explored at lat: 43.6783953 and long: -79.4008217, with 0 venues
# 164, venues of South Hill explored at lat: 43.6779261 and long: -79.4057671, with 0 venues
# 165, venues of Forest Hill SE explored at lat: 43.6935586 and long: -79.4139023, with 0 venues
# 166, venues of Deer Park explored at lat: 43.6977732 and long: -79.39690388301321, with 0 venues
# 167, venues of CN Tower explored at lat: 43.6425637 and long: -79.38708718320467, with 0 venues
# 168, venues of King and Spadina explored at lat: 43.6454561 and long: -79.3949942, with 0 venues
# 169, venues of Railway Lands explored at lat: 43.6465663 and long: -79.35106457413957, with 0 venues
# 170, venues of Harbourfront West explored at lat: 43.6400801 and long: -79.3801495, with 0 venues
# 171, venues of Bathurst Quay explored at lat: 43.6230544 and long: -79.39431563721035, with 0 venues
# 172, venues of Island airport explored at lat: 43.628057049999995 and long: -79.3979911558998, with 0 venues
# 173, venues of New Toronto explored at lat: 43.6534817 and long: -79.3839347, with 0 venues
# 174, venues of Mimico South explored at lat: 43.6147778 and long: -79.49372154486196, with 0 venues
# 175, venues of Humber Bay Shores explored at lat: 43.6056466 and long: -79.50132070000001, with 0 venues
# 176, venues of South Steeles explored at lat: 43.821912999999995 and long: -79.32859261645963, with 5 venues
# 177, venues of Silverstone explored at lat: 43.749750899999995 and long: -79.59911593109416, with 3 venues
# 178, venues of Humbergate explored at lat: 43.77656945 and long: -79.50690763304715, with 2 venues
# 179, venues of Jamestown explored at lat: 43.6449033 and long: -79.3818364, with 0 venues
# 180, venues of Mount Olive explored at lat: 43.6534817 and long: -79.3839347, with 0 venues
# 181, venues of Beaumond Heights explored at lat: 43.739416399999996 and long: -79.5884369, with 13 venues
# 182, venues of Thistletown explored at lat: 43.7372656 and long: -79.5653169, with 9 venues
# 183, venues of Albion Gardens explored at lat: 43.7398714 and long: -79.58480986358508, with 10 venues
# 184, venues of Steeles West explored at lat: 43.8161778 and long: -79.3145378, with 2 venues
# 185, venues of L'Amoreaux West explored at lat: 43.799003 and long: -79.3059669, with 4 venues
# 186, venues of Rosedale explored at lat: 43.6561192 and long: -79.38467, with 0 venues
# 187, venues of Stn A PO Boxes explored at lat: 43.6464352 and long: -79.37484599999999, with 0 venues
# 188, venues of Alderwood explored at lat: 43.601598 and long: -79.5473673, with 0 venues
# 189, venues of Long Branch explored at lat: 43.59200455 and long: -79.54536450659592, with 0 venues
# 190, venues of Northwest explored at lat: 43.6534817 and long: -79.3839347, with 0 venues
# 191, venues of West Humber - Clairville explored at lat: 43.706748299999994 and long: -79.5940544, with 1 venues
# 192, venues of Upper Rouge explored at lat: 43.8049304 and long: -79.1658374, with 10 venues
# 193, venues of St. James Town explored at lat: 43.6694032 and long: -79.3727041, with 0 venues
# 194, venues of Cabbagetown explored at lat: 43.6644734 and long: -79.3669861, with 0 venues
# 195, venues of First Canadian Place explored at lat: 43.6487681 and long: -79.38169179283025, with 0 venues
# 196, venues of Underground city explored at lat: 43.7701454 and long: -79.3748625, with 2 venues
# 197, venues of The Kingsway explored at lat: 43.6473811 and long: -79.5113328, with 0 venues
# 198, venues of Montgomery Road explored at lat: 43.709659200000004 and long: -79.39979008398667, with 0 venues
# 199, venues of Old Mill North explored at lat: 43.649826 and long: -79.4943338, with 0 venues
# 200, venues of Church and Wellesley explored at lat: 43.6626078 and long: -79.39103327552064, with 0 venues
# 201, venues of Business reply mail Processing Centre explored at lat: 43.6627439 and long: -79.321558, with 0 venues
# 202, venues of South Central Letter Processing Plant Toronto explored at lat: 43.6627439 and long: -79.321558, with 0 venues
# 203, venues of Old Mill South explored at lat: 43.649826 and long: -79.4943338, with 0 venues
# 204, venues of King's Mill Park explored at lat: 43.6510895 and long: -79.4920291, with 0 venues
# 205, venues of Sunnylea explored at lat: 43.64159705 and long: -79.5016654011084, with 0 venues
# 206, venues of Humber Bay explored at lat: 43.6400463 and long: -79.495028, with 0 venues
# 207, venues of Mimico NE explored at lat: 43.6166773 and long: -79.4968048, with 0 venues
# 208, venues of The Queensway East explored at lat: 43.6093093 and long: -79.5677317, with 0 venues
# 209, venues of Royal York South East explored at lat: 43.6534817 and long: -79.3839347, with 0 venues
# 210, venues of Kingsway Park South East explored at lat: 43.6473811 and long: -79.5113328, with 0 venues
# venues of Toronto are explored, the dataset shape is (489, 5)
#                                             name       categories        lat  \
# 0                             Shoppers Drug Mart         Pharmacy  43.759825
# 1    GoodLife Fitness Scarborough Cedarbrae Mall              Gym  43.759389
# 2                                         Subway   Sandwich Place  43.759307
# 3                                 RBC Royal Bank             Bank  43.760149
# 4                                    Pizza Pizza      Pizza Place  43.759321
# ..                                           ...              ...        ...
# 484                   Real Fruit Bubble Tea 真果茶坊  Bubble Tea Shop  43.806709
# 485                          Francois' No Frills    Grocery Store  43.808416
# 486                                  Telfer park             Park  43.807310
# 487                                    Starbucks      Coffee Shop  43.770037
# 488                                  Tim Hortons      Coffee Shop  43.770827
#
#            lng     neighbourhood
# 0   -79.225268         Parkwoods
# 1   -79.226409         Parkwoods
# 2   -79.224057         Parkwoods
# 3   -79.224908         Parkwoods
# 4   -79.224929         Parkwoods
# ..         ...               ...
# 484 -79.222759       Upper Rouge
# 485 -79.223520       Upper Rouge
# 486 -79.226403       Upper Rouge
# 487 -79.221156  Underground city
# 488 -79.223078  Underground city
#
# [489 rows x 5 columns]

# %%
df_venues.groupby('neighbourhood').count()
# Out:
#                   name  categories  lat  lng
# neighbourhood
# Agincourt            4           4    4    4
# Agincourt North     15          15   15   15
# Albion Gardens      10          10   10   10
# Bathurst Manor       4           4    4    4
# Bayview Village      5           5    5    5
# ...                ...         ...  ...  ...
# Wilson Heights      13          13   13   13
# Woburn              20          20   20   20
# Woodbine Gardens     2           2    2    2
# York Mills          13          13   13   13
# York Mills West      9           9    9    9
#
# [79 rows x 4 columns]

# %%
print('There are {} uniques categories \n'.format(len(df_venues['categories'].unique())))
print('There are {} uniques venues \n'.format(len(df_venues['name'].unique())))
# Out:
# There are 60 uniques categories
#
# There are 89 uniques venues
